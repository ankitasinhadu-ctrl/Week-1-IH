# %% [markdown]
# # OpenAI API Examples
#
# This notebook demonstrates various OpenAI API usage patterns including responses and chat completions.

# %% [markdown]
# ## Setup

# %%
# !pip install openai pydantic python-dotenv
# Out:
# Collecting openai
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pydantic in c:\users\user\anaconda3\lib\site-packages (2.12.4)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\anaconda3\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 8.6 MB/s  0:00:00
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Installing collected packages: jiter, openai
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.14.0 openai-2.32.0

# %%
import os
from openai import OpenAI
from pydantic import BaseModel
from typing import List
from dotenv import load_dotenv

# Initialize client
load_dotenv()  # Load environment variables from .env file
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# ## Using client.responses.create

# %% [markdown]
# ### Simple Client with Non-Reasoning Model

# %%
response = client.responses.create(
    model="gpt-4o",
    input="What is machine learning?"
)

print(response.output_text)
# Out:
# Machine learning is a branch of artificial intelligence (AI) that focuses on developing algorithms and statistical models that enable computers to learn and make decisions from data. Instead of being explicitly programmed to perform a task, machine learning algorithms use patterns and inference to improve their performance over time. This allows machines to adapt to new situations and improve accuracy by learning from experience.
#
# Key components of machine learning include:
#
# 1. **Data**: The foundation of machine learning. The quality and quantity of data directly impact the performance of machine learning models.
#
# 2. **Algorithms**: The mathematical procedures or formulas used by a machine to perform a task. Common algorithms include decision trees, neural networks, and support vector machines.
#
# 3. **Models**: Representations of what the machine has learned from the data. Models are used to make predictions or decisions without explicit programming.
#
# 4. **Training**: The process of feeding data into an algorithm to develop a model. During training, the algorithm adjusts the model based on the input data.
#
# 5. **Testing**: Evaluating the model's predictions against new, unseen data to assess its accuracy and effectiveness.
#
# Machine learning is used in various applications, including speech recognition, image processing, recommendation systems, and autonomous vehicles. It can be categorized into three primary types:
#
# 1. **Supervised Learning**: The model is trained on labeled data, where the outcomes are known. It learns to predict the output from the input data.
#
# 2. **Unsupervised Learning**: The model identifies patterns and relationships in data without pre-existing labels. It’s used for clustering and association.
#
# 3. **Reinforcement Learning**: The model learns through trial and error, receiving feedback from its actions to maximize rewards.
#
# Overall, machine learning enables systems to improve automatically through experience and find insights in data that might be difficult for humans to detect manually.

# %% [markdown]
# ### Client with Reasoning Model

# %%
response = client.responses.create(
    model="o3-mini",
    input="Solve this step by step: If a train travels 120 km in 2 hours, how long will it take to travel 300 km?"
)

print(response.output_text)

# %% [markdown]
# ### Image as Input

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "What's in this image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://upload.wikimedia.org/wikipedia/commons/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)

# %% [markdown]
# ### Temperature, Model, Instructions (Non-Reasoning)

# %%
response = client.responses.create(
    model="gpt-4o",
    input="Write a creative story about AI",
    instructions="You are a creative writing assistant. Write in a poetic style.",
    temperature=0.9
)

print(response.output_text)

# %% [markdown]
# ### Responses with Reasoning Effort

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    instructions="Talk like a pirate.",
    input="Are semicolons optional in JavaScript?",
)

print(response.output_text)

# %% [markdown]
# ### Alternative Response Formats

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    input=[
        {
            "role": "developer",
            "content": "Talk like a pirate."
        },
        {
            "role": "user",
            "content": "Are semicolons optional in JavaScript?"
        }
    ]
)

print(response.output_text)

# %% [markdown]
# ### Verbosity Parameter

# %%
response = client.responses.create(
    model="gpt-5.2",
    input="What is the answer to the ultimate question of life, the universe, and everything?",
    text={
        "verbosity": "low"
    }
)

print(response.output_text)

# %%
response = client.responses.create(
    model="gpt-5.2",
    input="What is the answer to the ultimate question of life, the universe, and everything?",
    text={
        "verbosity": "high"
    }
)

print(response.output_text)

# %% [markdown]
# ### Multiple Turns

# %%
response1 = client.responses.create(
    model="gpt-4o-mini",
    input="My name is Alice"
)

print("Turn 1:", response1.output_text)

response2 = client.responses.create(
    model="gpt-4o",
    input="What's my name?",
    previous_response_id=response1.id
)

print("\nTurn 2:", response2.output_text)

# %% [markdown]
# ### Roles (Developer, User, Assistant)

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    input=[
        {
            "role": "developer",
            "content": "Talk like a pirate."
        },
        {
            "role": "user",
            "content": "Are semicolons optional in JavaScript?"
        }
    ]
)

print(response.output_text)

# %% [markdown]
# ## Using client.chat.completions.create

# %% [markdown]
# ### Basic Messages Array

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain neural networks in one sentence."}
    ]
)

print(response.choices[0].message.content)

# %% [markdown]
# ### Structured Output with Pydantic

# %%
from pydantic import BaseModel

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

completion = client.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user", "content": "Alice and Bob are going to a science fair on Friday."},
    ],
    response_format=CalendarEvent,
)

event = completion.choices[0].message.parsed

# %% [markdown]
# ## Research Paper Extraction

# %%
from pydantic import BaseModel

class ResearchPaperExtraction(BaseModel):
    title: str
    authors: list[str]
    abstract: str
    keywords: list[str]

completion = client.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "You are an expert at structured data extraction. You will be given unstructured text from a research paper and should convert it into the given structure."},
        {"role": "user", "content": "..."}
    ],
    response_format=ResearchPaperExtraction,
)

research_paper = completion.choices[0].message.parsed

# %%
research_paper

# %% [markdown]
# ## Moderation

# %%
from enum import Enum
from typing import Optional
from pydantic import BaseModel

class Category(str, Enum):
    violence = "violence"
    sexual = "sexual"
    self_harm = "self_harm"

class ContentCompliance(BaseModel):
    is_violating: bool
    category: Optional[Category]
    explanation_if_violating: Optional[str]

completion = client.chat.completions.parse(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Determine if the user input violates specific guidelines and explain if they do."},
        {"role": "user", "content": "How do I prepare for a job interview?"}
    ],
    response_format=ContentCompliance,
)

compliance = completion.choices[0].message.parsed

# %%
compliance

# %%
completion = client.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "Determine if the user input violates specific guidelines and explain if they do."},
        {"role": "user", "content": "I want to hurt myself."}
    ],
    response_format=ContentCompliance,
)

compliance = completion.choices[0].message.parsed

# %%
compliance
